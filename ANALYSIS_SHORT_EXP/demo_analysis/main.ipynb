# %%
import pandas as pd

# %%
df=pd.read_csv('01_M_shortexp.csv')

# %%
df.columns
# Out:
# Index(['face_images', 'trials.thisRepN', 'trials.thisTrialN', 'trials.thisN',
#        'trials.thisIndex', 'thisRow.t', 'notes', 'instructions.started',
#        'text.started', 'instruct_resp.started', 'instructions.stopped',
#        'instruct_resp.keys', 'instruct_resp.rt', 'instruct_resp.duration',
#        'trial.started', 'image.started', 'valence_text.started',
#        'valence_slider.started', 'valence_text.stopped',
#        'valence_slider.stopped', 'arousal_text.started',
#        'arousal_slider.started', 'arousal_text.stopped',
#        'arousal_slider.stopped', 'emo_intense_text.started',
#        'emotional_intensity_slider.started', 'emo_intense_text.stopped',
#        'emotional_intensity_slider.stopped', 'familiar_text.started',
#        'familiarity_slider.started', 'familiar_text.stopped',
#        'familiarity_slider.stopped', 'emo_express_text.started',
#        'emotion_express_slider.started', 'emo_express_text.stopped',
#        'trial.stopped', 'valence_slider.response', 'valence_slider.rt',
#        'arousal_slider.response', 'arousal_slider.rt',
#        'emotional_intensity_slider.response', 'emotional_intensity_slider.rt',
#        'familiarity_slider.response', 'familiarity_slider.rt',
#        'emotion_express_slider.response', 'emotion_express_slider.rt',
#        'end.started', 'text_2.started', 'text_2.stopped', 'end.stopped',
#        'participant', 'session', 'date', 'expName', 'psychopyVersion',
#        'frameRate', 'expStart', 'Unnamed: 57'],
#       dtype='object')

# %%
cols_to_take=[
    'face_images',
    'valence_slider.response', 'valence_slider.rt',
    'arousal_slider.response', 'arousal_slider.rt',
    'emotional_intensity_slider.response', 'emotional_intensity_slider.rt',
    'familiarity_slider.response', 'familiarity_slider.rt',
    'emotion_express_slider.response', 'emotion_express_slider.rt'
]

# %%
df=df[cols_to_take]

# %%
# Assuming 'df' is your DataFrame and 'face_images' is the column to check for NULL values
df = df.dropna(subset=['face_images'])

# %%
df
# Out:
#         face_images  valence_slider.response  valence_slider.rt  \
# 1    images/4n.tiff                      3.0           9.611617
# 2    images/5n.tiff                      1.0           3.452936
# 3    images/5h.tiff                      6.0           3.699541
# 4   images/10h.tiff                      5.0          24.585888
# 5   images/10n.tiff                      4.0           4.240272
# 6   images/18n.tiff                      4.0           4.438262
# 7    images/10.tiff                      3.0          10.450813
# 8    images/18.tiff                      1.0           4.897505
# 9   images/18h.tiff                      6.0           5.272347
# 10   images/4h.tiff                      6.0           4.120258
# 11    images/5.tiff                      1.0           3.605302
# 12    images/4.tiff                      1.0           1.794737
#
#     arousal_slider.response  arousal_slider.rt  \
# 1                       3.0          41.773979
# 2                       1.0           5.084986
# 3                       5.0           8.183306
# 4                       6.0          28.923263
# 5                       3.0           9.217386
# 6                       3.0           7.323307
# 7                       4.0          13.960283
# 8                       1.0           6.916322
# 9                       5.0           7.024272
# 10                      5.0           6.312081
# 11                      2.0           4.411868
# 12                      1.0           2.733026
#
#     emotional_intensity_slider.response  emotional_intensity_slider.rt  \
# 1                                   2.0                      45.118902
# 2                                   6.0                       7.072457
# 3                                   6.0                      10.784150
# 4                                   6.0                      32.843476
# 5                                   4.0                      12.403687
# 6                                   5.0                       9.337170
# 7                                   6.0                      17.400927
# 8                                   6.0                       9.197075
# 9                                   6.0                       9.092175
# 10                                  6.0                       7.604575
# 11                                  1.0                       5.479167
# 12                                  6.0                       6.186866
#
#     familiarity_slider.response  familiarity_slider.rt  \
# 1                           5.0              65.353782
# 2                           6.0              19.475570
# 3                           6.0              17.483397
# 4                           5.0              35.343675
# 5                           3.0              15.037076
# 6                           5.0              14.183692
# 7                           2.0              21.287629
# 8                           2.0              24.599471
# 9                           5.0              10.686125
# 10                          6.0               9.464891
# 11                          2.0               7.377504
# 12                          1.0              10.366710
#
#     emotion_express_slider.response  emotion_express_slider.rt
# 1                               3.0                  69.151443
# 2                               2.0                  25.091638
# 3                               1.0                  19.180290
# 4                               1.0                  37.054087
# 5                               3.0                  17.388724
# 6                               3.0                  16.280907
# 7                               4.0                  25.771390
# 8                               2.0                  26.443576
# 9                               1.0                  13.609792
# 10                              1.0                  10.921812
# 11                              2.0                  10.328063
# 12                              2.0                  12.037731

# %%
df.to_csv('01_M_shortexp_cleaned.csv', index=True)
